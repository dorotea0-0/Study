# %% [markdown]
# # Проверочное задание

# %% [markdown]
# # 🏃‍♂️🤸‍♂️🏋️‍♀️
# Сегодня вы аналитики популярной сети фитнес-клубов, которая предлагает три вида тренировок для взрослых и детей:
# - Обычное занятие в зале,
# - Сайклинг (кардиотренировка на велотренажёре),
# - Функциональная тренировка.
#
# Первая тренировка в наших клубах всегда бесплатная.
#
# Доступна следующая выгрузка данных:
# - О наших клиентах — `users.xlsx`,
#
# - Об оплатах тренировок — `payments.xlsx`,
#
# - О посещении тренировок — `workouts.csv`.
#
# Директор  сети и попросил ответить на вопросы, которые позволят более точно сформулировать планы на следующий год:
#
# 1. Как изменялась ежемесячная выручка по каждому типу тренировок в течение 2020 года?
# 2. Какие тренеры в сети провели больше всего платных занятий за все время?
# 3. Сколько денег и за какие типы тренировок принесли клиенты, которые начали заниматься в ноябре?
# 4. Какие регионы приносят нашей сети больше всего и меньше всего выручки? Результаты регионов будут обсуждаться на совете директоров, поэтому необходимо выгрузить этот отчет в файл формата Excel, чтобы включить его в раздаточный материал для совещания.
#
# Выполнив следующие четыре задания, вы сможете последовательно ответить на все вопросы руководителя. Для начала убедитесь, что три новых файла с данными скачаны в папку с этим ноутбуком, импортируй нужные библиотеки и загрузи данные в датафреймы.

# %%
import pandas as pd
from datetime import datetime

users = pd.read_excel("users.xlsx") # загружаем данные по клиентам
payments = pd.read_excel("payments.xlsx") # загружаем данные по платежам
workouts = pd.read_csv("workouts.csv") # загружаем данные по тренировкам

pd.set_option('display.float_format', lambda x: '%.2f' % x) # эта строка поможет удобно выводить большие числа в этом ноутбуке

# %% [markdown]
# ## Задание 1
#
# Подготовь данные для ответа на вопрос: «__Как изменялась ежемесячная выручка по каждому типу тренировок в течение 2020 года?__».
#
# ### Как это сделать?
#
# 1. Изучи датафрейм `payments` и для начала переведи даты в формат `datetime`.
#
# 2. С помощью фильтрации датафрейма выбери платежи только за 2020 год.
#
# 3. Обрати внимание, что платежи хранятся в разных валютах — для удобства приведем все к рублям. Сначала добавь в датафрейм столбец `fx_rate` с курсом валюты и заполни его с помощью метода `apply()`: если это USD, то берем значение переменной `USD_RATE`, если RUR — ставим значение `1`. Предварительно нужно определить функцию, которая реализует эту несложную логику.
#
# 4. Добавь еще один столбец `amount_rub` с суммой платежа в рублях. Для этого умножь столбец с суммой платежа на столбец `fx_rate` с курсом валют.
#
# 5. Получи датафрейм с разбивкой выручки по месяцам и по типам тренировок с помощью группировки с суммой методом `groupby()`.
#
# 6. Выведи результат на экран.
#
# 🤔 *Предположи, основываясь на проделанном анализе.* Благодаря каким тренировкам компания могла получать больше выручки? У этого задания нет правильного ответа,  предлагается некое размышление.

# %%
USD_RATE = 73.14 # курс доллара

payments['payment_date'] = pd.to_datetime(payments['payment_date'], errors='coerce')
payments
# Out:
#        user_id  payment_id workout_type  amount payment_date currency  \
# 0       193433        3733      general 7522.49   2019-06-04      RUR
# 1       193433       12219      general 8346.04   2019-08-05      RUR
# 2       329226       13733      general 8707.38   2019-08-09      RUR
# 3       193433       14602      general 7432.49   2019-12-04      RUR
# 4       193433       14603      general  114.64   2019-08-04      RUR
# ...        ...         ...          ...     ...          ...      ...
# 20790  3301629     2931094      general 8358.33   2020-12-05      RUR
# 20791  4294927     2931391      general 8477.52   2020-07-10      RUR
# 20792  2181319     2931540      general 9409.41          NaT      RUR
# 20793  5505898  1000012868      general 8918.91   2020-02-03      RUR
# 20794  2915674  1000022868      general 8103.84   2020-06-06      RUR
#
#        fx_rate  amount_rub
# 0         1.00     7522.49
# 1         1.00     8346.04
# 2         1.00     8707.38
# 3         1.00     7432.49
# 4         1.00      114.64
# ...        ...         ...
# 20790     1.00     8358.33
# 20791     1.00     8477.52
# 20792     1.00     9409.41
# 20793     1.00     8918.91
# 20794     1.00     8103.84
#
# [20795 rows x 8 columns]

# %%
def get_fx_rate(row):
    if row['currency'] == 'USD':
        return USD_RATE
    elif row['currency'] == 'RUR':
        return 1

# %%
payments['fx_rate'] = payments.apply(get_fx_rate, axis=1)

# %%
payments.head(3)
# Out:
#    user_id  payment_id workout_type  amount payment_date currency  fx_rate
# 0   193433        3733      general 7522.49   2019-06-04      RUR     1.00
# 1   193433       12219      general 8346.04   2019-08-05      RUR     1.00
# 2   329226       13733      general 8707.38   2019-08-09      RUR     1.00

# %%
payments['amount_rub']=payments['amount']*payments['fx_rate']
payments.head(3)
# Out:
#    user_id  payment_id workout_type  amount payment_date currency  fx_rate  \
# 0   193433        3733      general 7522.49   2019-06-04      RUR     1.00
# 1   193433       12219      general 8346.04   2019-08-05      RUR     1.00
# 2   329226       13733      general 8707.38   2019-08-09      RUR     1.00
#
#    amount_rub
# 0     7522.49
# 1     8346.04
# 2     8707.38

# %%
payments_2020 = payments[payments['payment_date'].dt.year == 2020]
payments_2020.head(3)
# Out:
#       user_id  payment_id workout_type  amount payment_date currency  fx_rate  \
# 9437  3187806     2138734      general 8801.06   2020-12-10      RUR     1.00
# 9441  1808104     2138983      cycling 8918.91   2020-10-04      RUR     1.00
# 9442   763754     2138995      general 8358.33   2020-09-04      RUR     1.00
#
#       amount_rub
# 9437     8801.06
# 9441     8918.91
# 9442     8358.33

# %%
revenue_by_month_workout = payments_2020.groupby([payments_2020['payment_date'].dt.month, 'workout_type'])['amount_rub'].sum().reset_index()

# %%
print(revenue_by_month_workout)
# Out:
#     payment_date     workout_type  amount_rub
# 0              1          cycling    26897.96
# 1              1          general  7253057.89
# 2              2          cycling    56582.47
# 3              2  functional test     7110.81
# 4              2          general  6280836.33
# 5              3          cycling    18858.59
# 6              3          general  8319324.98
# 7              4          cycling    19555.14
# 8              4  functional test    14806.35
# 9              4          general  7909215.68
# 10             5          cycling    34563.65
# 11             5          general 10580435.04
# 12             6          cycling    27136.20
# 13             6  functional test     7800.90
# 14             6          general  6061313.58
# 15             7          cycling    25721.43
# 16             7  functional test     7900.90
# 17             7          general  9387873.39
# 18             8          cycling    77083.67
# 19             8  functional test     7900.90
# 20             8          general  8605382.78
# 21             9          cycling   824350.22
# 22             9          general  7554212.11
# 23            10          cycling   811344.97
# 24            10  functional test     7795.54
# 25            10          general  9263130.35
# 26            11          cycling    38886.99
# 27            11  functional test     9050.01
# 28            11          general  6924224.50
# 29            12          cycling    86164.82
# 30            12          general  5971046.09

# %% [markdown]
# ## Задание 2
#
# Определи, __какой тренер в сети провел больше всего платных занятий за все время__. С самыми эффективными сотрудниками мы организуем интервью, чтобы понять, что влияет на их результат.
#
# ### Как это сделать?
#
# 1. Изучи датафрейм `workouts`.
#
# 2. Исключи из датафрейма тренеров из департамента `Sales`, так как они проводят только бесплатные тренировки, а нам интересны только платные занятия.
#
# 3. Сделай группировку по `trainer_id` и выведи количество уникальных тренировок по `workout_id`.
#
# 4. Найди максимальное количество тренировок и сохрани его в переменную `max_trainings`. Не забудь, что после группировки в прошлом пункте, индексом стал столбец `trainer_id`. Возможно, тебе понадобится метод, который возвращает индексы в колонки.
#
# 5. Выведи на экран id тренера, у которого количество тренировок равно значению `max_trainings`.

# %%
workouts.head(3)
# Out:
#    workout_id   cost          start_at   status workout_schedule_type  \
# 0    30793909    NaN  2020-11-13 12:45  success                 trial
# 1    31123309 750.00  2020-11-21 13:00  success               regular
# 2    31412167 750.00  2020-11-28 13:00  success               regular
#
#    client_id client_status workout_type trainer_department  trainer_id  \
# 0   22034.00           NaN      general              Sales 10722051.00
# 1   22034.00           new      general          Spartacus   940642.00
# 2   22034.00           new      general          Spartacus   940642.00
#
#   currency
# 0      RUR
# 1      RUR
# 2      RUR

# %%
df=workouts.loc[workouts['trainer_department']!='Sales']
df.head(3)
# Out:
#    workout_id   cost          start_at   status workout_schedule_type  \
# 1    31123309 750.00  2020-11-21 13:00  success               regular
# 2    31412167 750.00  2020-11-28 13:00  success               regular
# 3    31703605 750.00  2020-12-05 13:00  success               regular
#
#    client_id client_status workout_type trainer_department  trainer_id  \
# 1   22034.00           new      general          Spartacus   940642.00
# 2   22034.00           new      general          Spartacus   940642.00
# 3   22034.00        active      general          Spartacus   940642.00
#
#   currency
# 1      RUR
# 2      RUR
# 3      RUR

# %%
df_z2_2 = df.groupby('trainer_id')['workout_id'].nunique()
df_z2_2.head(3)
# Out:
# trainer_id
# 3249.00     4
# 14431.00    7
# 24646.00    4
# Name: workout_id, dtype: int64

# %%
df_z2_2=df_z2_2.reset_index()
df_z2_2
# Out:
#      trainer_id  workout_id
# 0       3249.00           4
# 1      14431.00           7
# 2      24646.00           4
# 3      41793.00          35
# 4      59597.00          34
# ..          ...         ...
# 600 10361693.00           2
# 601 10380260.00          26
# 602 10383863.00          10
# 603 10676833.00          15
# 604 10824707.00           5
#
# [605 rows x 2 columns]

# %%
df_z2_2_2=df_z2_2.sort_values(by='workout_id', ascending=False)
df_z2_2_2['trainer_id'].head(1)
# Out:
# 10824707.0

# %% [markdown]
# ## Задание 3
#
# Посчитайте, __сколько денег и за какие типы тренировок принесли клиенты, которые начали заниматься в ноябре__.
#
# ### Как это сделать?
#
# 1. Изучи датафрейм `users` и переведи даты в формат `datetime`.
# 2. Отбери только тех клиентов, кто начал заниматься с 1 по 30 ноября 2020 года, код уже готов, обрати внимание, как можно передать сразу 2 условия в `loc[]`
# 3. Объедини получившийся набор данных с платежами из датафрейма `payments` по `user_id`.
#
# 4. Сгруппируй результат по `workout_type` и найди сумму по `amount_rub`.

# %%
users['free_workout_datetime'] =pd.to_datetime(users['free_workout_datetime'], errors='coerce')    # переведи даты в формат datetime

november_users = users.loc[(users['free_workout_datetime']>=datetime(2020,11,1))   # отобрали клиентов, кто начал заниматься с 1 ноября
                           &(users['free_workout_datetime']<datetime(2020,12,1))]  # по 30 ноября 2020 года
november_users.head(3)
# Out:
#    first_contact_datetime   age free_workout_datetime first_payment_datetime  \
# 11    2018-03-04 14:05:25 12.00   2020-11-16 18:20:00    2020-11-18 10:29:44
# 24    2018-11-08 15:26:25 10.00   2020-11-20 17:00:00    2020-11-20 17:35:57
# 41    2020-11-06 21:55:59 21.00   2020-11-16 18:15:00    2020-11-16 18:46:29
#
#     workouts_successful  workouts_total  months_active  user_id  \
# 11                    5               5              2  1398709
# 24                    5               5              2  2975028
# 41                    6               6              2  2836636
#
#                          region geo_group
# 11  Москва и Московская область    Москва
# 24  Москва и Московская область    Москва
# 41                          NaN       СНГ

# %%
df_new1=pd.merge(november_users, payments, how='left',
                left_on='user_id', right_on='user_id')
df_new1.head(3)
# Out:
#   first_contact_datetime   age free_workout_datetime first_payment_datetime  \
# 0    2018-03-04 14:05:25 12.00   2020-11-16 18:20:00    2020-11-18 10:29:44
# 1    2018-11-08 15:26:25 10.00   2020-11-20 17:00:00    2020-11-20 17:35:57
# 2    2020-11-06 21:55:59 21.00   2020-11-16 18:15:00    2020-11-16 18:46:29
#
#    workouts_successful  workouts_total  months_active  user_id  \
# 0                    5               5              2  1398709
# 1                    5               5              2  2975028
# 2                    6               6              2  2836636
#
#                         region geo_group  payment_id workout_type  amount  \
# 0  Москва и Московская область    Москва  2817467.00      cycling 8759.56
# 1  Москва и Московская область    Москва  2829176.00      general 9744.62
# 2                          NaN       СНГ  2809454.00      general 9316.76
#
#   payment_date currency  fx_rate  amount_rub
# 0          NaT      RUR     1.00     8759.56
# 1   2020-10-09      RUR     1.00     9744.62
# 2          NaT      RUR     1.00     9316.76

# %%
sum = df_new1.groupby('workout_type')['amount_rub'].sum()

# %%
sum=sum.reset_index()
sum
# Out:
#   workout_type  amount_rub
# 0      cycling    77676.28
# 1      general  5636628.32

# %% [markdown]
# ## Задание 4
#
# Выясни, **какие регионы приносят нашей сети больше всего и меньше всего выручки**.
#
# ### Как это сделать
#
# 1. Создай новый датафрейм `user_regions` из колонок `user_id` и `region` датафрейма `users`.
#
# 2. Создай новый датафрейм `user_payments` из колонок `user_id` и `amount_rub` датафрейма `payments`.
# 3. C помощью `.merge()` объедини датафреймы `user_regions` и `user_payments`
# 4. Обрати внимание, что у некоторых клиентов не заполнен регион. `dropna()` — хороший метод для очистки датасета от строк, в которых не хватает каких-то значений.
# 5. Сгруппируй данные о выручке по региону, а затем отсортируй их.
# 6. Выведи на экран топ-5 регионов с самой маленькой выручкой.
# 7. Выведи на экран топ-5 регионов с самой большой выручкой.
# 8. Сохрани отсортированный по убыванию список регионов с выручкой в файл `task_fitnes.xlsx` с помощью метода `to_excel()`.
#
# 🤔 *Предположи, основываясь на проделанном анализе.* Как сейчас распределялась
# выручка между регионами? У этого задания нет правильного ответа, можно поразмышлять.

# %%
user_regions=users.loc[:, 'user_id':'region']
user_regions.head(3)
# Out:
#    user_id region
# 0  2790000    NaN
# 1   780106    NaN
# 2  1133376    NaN

# %%
user_payments=payments.loc[:, ['user_id','amount_rub']]
user_payments.head(3)
# Out:
#    user_id  amount_rub
# 0   193433     7522.49
# 1   193433     8346.04
# 2   329226     8707.38

# %%
df_new2=pd.merge(user_payments, user_regions, how='left',
                left_on='user_id', right_on='user_id')
df_new2.head(3)
# Out:
#    user_id  amount_rub                       region
# 0   193433     7522.49                          NaN
# 1   193433     8346.04                          NaN
# 2   329226     8707.38  Москва и Московская область

# %%
df_new3=df_new2.dropna()
df_new3.head(3)
# Out:
#     user_id  amount_rub                       region
# 2    329226     8707.38  Москва и Московская область
# 7    116239     8816.13  Москва и Московская область
# 10  1057268     9177.15             Липецкая область

# %%
df_new4=df_new3.groupby('region')['amount_rub'].sum()

df_new4=df_new4.reset_index()

# %%
df_new6=df_new4.sort_values(by='amount_rub', ascending=True)
df_new6.head(5)
# Out:
#                  region  amount_rub
# 30  Магаданская область     8938.74
# 49  Республика Калмыкия     9277.15
# 11         Еврейская АО    19615.55
# 29    Луганская область    19703.92
# 45     Республика Алтай    20172.72

# %%
df_new5=df_new4.sort_values(by='amount_rub', ascending=False)
df_new5.head(5)
# Out:
#                                      region   amount_rub
# 32              Москва и Московская область 121137445.26
# 62  Санкт-Петербург и Ленинградская область  26429453.52
# 36                    Новосибирская область   4968301.32
# 24                       Краснодарский край   4061682.64
# 56                     Республика Татарстан   3891956.28

# %%
df_new5.to_excel('task_fitnes.xlsx', sheet_name='Sheet1', index=False)

# %% [markdown]
# # 🎉🎉🎉

# %%
payments
# Out:
#        user_id  payment_id workout_type  amount payment_date currency  \
# 0       193433        3733      general 7522.49   2019-06-04      RUR
# 1       193433       12219      general 8346.04   2019-08-05      RUR
# 2       329226       13733      general 8707.38   2019-08-09      RUR
# 3       193433       14602      general 7432.49   2019-12-04      RUR
# 4       193433       14603      general  114.64   2019-08-04      RUR
# ...        ...         ...          ...     ...          ...      ...
# 20790  3301629     2931094      general 8358.33   2020-12-05      RUR
# 20791  4294927     2931391      general 8477.52   2020-07-10      RUR
# 20792  2181319     2931540      general 9409.41          NaT      RUR
# 20793  5505898  1000012868      general 8918.91   2020-02-03      RUR
# 20794  2915674  1000022868      general 8103.84   2020-06-06      RUR
#
#        fx_rate  amount_rub
# 0         1.00     7522.49
# 1         1.00     8346.04
# 2         1.00     8707.38
# 3         1.00     7432.49
# 4         1.00      114.64
# ...        ...         ...
# 20790     1.00     8358.33
# 20791     1.00     8477.52
# 20792     1.00     9409.41
# 20793     1.00     8918.91
# 20794     1.00     8103.84
#
# [20795 rows x 8 columns]
